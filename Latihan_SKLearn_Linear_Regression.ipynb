# %% [markdown]
# <a href="https://colab.research.google.com/github/Tambunan26/Machine-Learning/blob/master/Latihan_SKLearn_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# Buat data jumlah kamar
bedrooms = np.array([1,1,2,2,3,4,4,5,5,5])
# Data harga rumah, asumsi dalam dollar
house_price = np.array([15000, 18000, 27000, 34000, 50000, 68000, 65000, 81000, 85000, 90000])
# Menampilkan scatter plot dari dataset
# %matplotlib inline
plt.scatter(bedrooms, house_price)
# Melatih model
from sklearn.linear_model import LinearRegression
bedrooms = bedrooms.reshape(-1, 1)
linreg = LinearRegression()
linreg.fit(bedrooms, house_price)
# Membuat plot dari model
plt.scatter(bedrooms, house_price)
plt.plot(bedrooms, linreg.predict(bedrooms))
